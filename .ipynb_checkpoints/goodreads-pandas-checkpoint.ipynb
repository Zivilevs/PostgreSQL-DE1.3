# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('books_1.Best_Books_Ever.csv')

# %%
df.describe()
# Out:
#              rating    numRatings  likedPercent      bbeScore      bbeVotes
# count  52478.000000  5.247800e+04  51856.000000  5.247800e+04  52478.000000
# mean       4.021878  1.787865e+04     92.231545  1.984023e+03     22.529003
# std        0.367146  1.039448e+05      5.990689  3.515314e+04    369.158541
# min        0.000000  0.000000e+00      0.000000  0.000000e+00     -4.000000
# 25%        3.820000  3.410000e+02     90.000000  8.400000e+01      1.000000
# 50%        4.030000  2.307000e+03     94.000000  9.700000e+01      1.000000
# 75%        4.230000  9.380500e+03     96.000000  1.870000e+02      2.000000
# max        5.000000  7.048471e+06    100.000000  2.993816e+06  30516.000000

# %%
df.columns
# Out:
# Index(['bookId', 'title', 'series', 'author', 'rating', 'description',
#        'language', 'isbn', 'genres', 'characters', 'bookFormat', 'edition',
#        'pages', 'publisher', 'publishDate', 'firstPublishDate', 'awards',
#        'numRatings', 'ratingsByStars', 'likedPercent', 'setting', 'coverImg',
#        'bbeScore', 'bbeVotes', 'price'],
#       dtype='object')

# %%
df0 = df.drop_duplicates()
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52428 entries, 0 to 52477
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bookId            52428 non-null  object
#  1   title             52428 non-null  object
#  2   series            23445 non-null  object
#  3   author            52428 non-null  object
#  4   rating            52428 non-null  float64
#  5   description       51092 non-null  object
#  6   language          48627 non-null  object
#  7   isbn              52428 non-null  object
#  8   genres            52428 non-null  object
#  9   characters        52428 non-null  object
#  10  bookFormat        50955 non-null  object
#  11  edition           4949 non-null   object
#  12  pages             50085 non-null  object
#  13  publisher         48736 non-null  object
#  14  publishDate       51549 non-null  object
#  15  firstPublishDate  31125 non-null  object
# ...

# %%
df0['bookId'].nunique()
# Out:
# 52424

# %%
dft = df0.groupby('bookId').count()

# %%
for i in dft.columns:
    print(i)
    print(dft[dft[i] > 1])
# Out:
# title
#                             title  series  author  rating  description  \
# bookId
# 24903989-widz-ci                2       2       2       2            2
# 60614.Diamond_Dogs              2       0       2       2            2
# 635270.The_Planet_Pirates       2       2       2       2            2
# 975953.Time_of_the_Dragons      2       2       2       2            2
#
#                             language  isbn  genres  characters  bookFormat  \
# bookId
# 24903989-widz-ci                   2     2       2           2           2
# 60614.Diamond_Dogs                 2     2       2           2           2
# 635270.The_Planet_Pirates          2     2       2           2           2
# 975953.Time_of_the_Dragons         2     2       2           2           2
#
#                             edition  pages  publisher  publishDate  \
# bookId
# 24903989-widz-ci                  0      2          2            2
# ...

# %%
df0[df0['bookId']=='27111181-paradox-effect']
# Out:
#                        bookId  \
# 1538  27111181-paradox-effect
#
#                                                   title series  \
# 1538  Paradox Effect: Time Travel and Purified DNA M...    NaN
#
#                  author  rating  \
# 1538  Gabriel F.W. Koch    4.37
#
#                                             description language  \
# 1538  In 2554, the World is Coming to its End, unles...      NaN
#
#                isbn                                        genres characters  \
# 1538  9781478756224  ['Fiction', 'Contemporary', 'Epic', 'Drama']         []
#
#      bookFormat edition pages        publisher          publishDate  \
# 1538  Paperback     NaN   284  Outskirts Press  September 27th 2015
#
#      firstPublishDate awards  numRatings                    ratingsByStars  \
# 1538              NaN     []        1524  ['719', '705', '53', '35', '12']
#
#       likedPercent setting                                           coverImg  \
# ...

# %%
df0.groupby(['bookId'])['price'].count().sort_values(ascending=False)
# Out:
# bookId
# 60614.Diamond_Dogs                          2
# 635270.The_Planet_Pirates                   2
# 975953.Time_of_the_Dragons                  2
# 24903989-widz-ci                            2
# 27111181-paradox-effect                     1
#                                            ..
# 17825503-leo                                0
# 40500085                                    0
# 17826001-titanic                            0
# 40496.How_Green_Was_My_Valley               0
# 1.Harry_Potter_and_the_Half_Blood_Prince    0
# Name: price, Length: 52424, dtype: int64

# %%
dft = df0.copy()
pat = r'\.(\d{3})'
repl = lambda m: m.group().replace(".", "")
dft['price'] = dft['price'].str.replace(pat, repl, regex=True)
dft[dft['bookId']=='3018318']

#df0['price'] = df0['price'].astype('float')
#df0['price'] = df0['price'].mean() '1.189.88'
# Out:
#        bookId   title series           author  rating  \
# 5067  3018318  جدارية    NaN  Mahmoud Darwish    4.31
#
#                                             description language  \
# 5067  "هزمتك يا موت الفنون جميعها"هكذا وفي عبارة واح...   Arabic
#
#                isbn                                             genres  \
# 5067  9781855134966  ['Poetry', 'Literature', 'Philosophy', 'Anthol...
#
#      characters bookFormat edition pages                publisher publishDate  \
# 5067         []  Paperback     NaN   105  رياض الريس للكتب والنشر        2001
#
#      firstPublishDate          awards  numRatings  \
# 5067         10/28/00  ['رياض الريس']        5502
#
#                             ratingsByStars  likedPercent setting  \
# 5067  ['3033', '1505', '689', '199', '76']          95.0      []
#
#                                                coverImg  bbeScore  bbeVotes  \
# 5067  https://i.gr-assets.com/images/S/compressed.ph...       582         6
#
#         price
# ...

# %%
dft['price'] = dft['price'].astype('double').mean().round(2)
dft.groupby(['bookId'])['price'].count().sort_values(ascending=False)
# Out:
# bookId
# 24903989-widz-ci                            2
# 635270.The_Planet_Pirates                   2
# 975953.Time_of_the_Dragons                  2
# 60614.Diamond_Dogs                          2
# 1.Harry_Potter_and_the_Half_Blood_Prince    1
#                                            ..
# 19271017-my-story                           1
# 1927111.Love_Com_Vol_5                      1
# 1927112.Love_Com_Vol_6                      1
# 192722.Candle_in_the_Darkness               1
# 999985.Horrid_Henry_s_Underpants            1
# Name: price, Length: 52424, dtype: int64

# %%
dft[dft['bookId']=='60614.Diamond_Dogs']
# Out:
#                    bookId         title series                        author  \
# 37401  60614.Diamond_Dogs  Diamond Dogs    NaN  Alan Watt (Goodreads Author)
# 37455  60614.Diamond_Dogs  Diamond Dogs    NaN  Alan Watt (Goodreads Author)
#
#        rating                                        description language  \
# 37401    3.46  Neil Garvin is a seventeen year old living in ...  English
# 37455    3.46  Neil Garvin is a seventeen year old living in ...  English
#
#                 isbn                                   genres characters  \
# 37401  9780446677844  ['Fiction', 'Mystery', 'Coming Of Age']         []
# 37455  9780446677844  ['Fiction', 'Mystery', 'Coming Of Age']         []
#
#       bookFormat edition pages                 publisher         publishDate  \
# 37401  Paperback     NaN   256  Grand Central Publishing  September 1st 2001
# 37455  Paperback     NaN   256  Grand Central Publishing  September 1st 2001
#
# ...

# %%
df1 = df0.drop_duplicates(subset='bookId')

# %% [markdown]
# ## 1NF
